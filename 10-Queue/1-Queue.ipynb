# %% [markdown]
# # 📌 1. What is a Queue? (Basics for Beginner)
#
# Think of a queue in real life – like a line of people waiting at a ticket counter.
#
# The first person who enters the line will get served first → FIFO (First In First Out).
#
# New people join at the back (enqueue).
#
# People leave from the front (dequeue).
#
# # 📌 Key Operations
#
# enqueue() → Add item at the back of the queue
#
# dequeue() → Remove item from the front
#
# peek() → Just see who is at the front (don’t remove)
#
# isEmpty() → Check if queue has no elements
#
# isFull() (only for fixed-size queue) → Check if queue is full
#
# # 📌 2. What to Study First (Step-by-Step)
#
# As a beginner, here’s the order you should learn queues:
#
# ✅ Step 1: Understand FIFO concept with a simple list.
#
# ✅ Step 2: Learn how to implement enqueue & dequeue manually using list (append + pop(0)).
#
# ✅ Step 3: Learn how to implement queue with fixed size (circular queue).
#
# ✅ Step 4: Learn how to implement queue using Linked List.
#
# ✅ Step 5: Learn Python’s built-in modules (queue.Queue, collections.deque, multiprocessing.Queue).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Queue")
