# %% [markdown]
# ### 📘 Array in DSA
# ### ✅ What is an Array?
# An array is a collection of elements (of same data type) stored at contiguous memory locations.

# %%
arr = [10, 20, 30, 40]  # Python array (list)
print(arr)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# # ✅ Why Use Arrays?
#
# Easy to access elements by index.
#
# Efficient for storing multiple values.
#
# Useful in building complex data structures (stacks, queues, etc.).

# %% [markdown]
# # ✅ Properties of Array (with Code)
#
# * Fixed Size (in low-level languages)
# Python lists grow dynamically, but in C/C++, array size is fixed.
#
# * Same Data Type
# Python allows mixed types, but in DSA logic, we assume same types.
#
# * Index-based Access

# %%
arr = [10, 20, 30, 40]  # Python array (list)
print(arr[1])
# Out:
# 20

# %%
print(arr[2])
# Out:
# 30

# %% [markdown]
# * Contiguous Memory Allocation (C/C++ specific)

# %% [markdown]
# # ✅ Types of Arrays
# Type	Description
#
# 1D Array	Simple list of elements
#
# 2D Array	Matrix (rows × cols)
#
# Multidimensional	Array within array (3D, 4D etc.)

# %%
arr1d = [1,2,3] #1d array
arr2d = [[1,2], [3,4]]
print(arr2d[1][1])
print(arr2d[0][0])
# Out:
# 4
# 1

# %% [markdown]
# # ✅ Operations on Array
#
# Operation
#
# * Traverse	 -  Loop through array
# * Insertion	 -  Add element
# * Deletion   -  Remove element
# * Search	 -  Find an element
# * Update	 -  Modify element

# %% [markdown]
# # ✅ Advantages
# Easy to implement.
#
# Index-based access (O(1) time).
#
# Better cache locality.
#
# # ✅ Disadvantages
#
# Fixed size (in some languages).
#
# Costly insertion/deletion (O(n) time).
#
# Wastes memory if partially filled.

# %% [markdown]
# ## 🔍 What is Traversal in Array?
# Traversal means visiting each element of an array one by one, usually to:
#
# Print
#
# Search
#
# Modify
#
# Apply operations (like sort, sum, etc.)

# %% [markdown]
# 📌 Examples

# %%
arr = [10, 20, 30,40, 50]

# %% [markdown]
# # 📂 Types of Array Traversal
# # ✅ 1. Linear Traversal
#
# ➡️ Visiting elements from start to end.

# %%
aar = [1,2,3,4,5]
print("Linear traverse :", end = " ")
for i in aar: # i = 1 , 
    print(i, end= " ")
# Out:
# Linear traverse : 1 2 3 4 5

# %% [markdown]
# # 🔁 2. Reverse Traversal
#
# ➡️ Visiting elements from end to start.

# %% [markdown]
# range(start, stop, step)
#
# start → where the loop begins
#
# stop → where the loop stops (exclusive)
#
# step → increment or decrement

# %% [markdown]
# 💡 Here:
#
# start = len(arr) - 1 → last index of the array
#
# stop = -1 → because Python’s range excludes the stop value, this makes the loop go down to index 0
#
# step = -1 → means we are moving backward

# %%
arr_rev = [1,2,3,4,5]
print("Reverse traverse :", end = " ")
for i in range(len(arr_rev)-1, -1, -1):
    print(arr_rev[i], end = " ")
# Out:
# Reverse traverse : 5 4 3 2 1

# %% [markdown]
# # 🔄 Methods to Traverse an Array

# %% [markdown]
# # 🌀 1. Using For Loop

# %%
arr = [10, 20, 30, 40, 50]
print(" traverse using for loop :", end = " ")
for i in range(len(arr)):
    print(arr[i], end = " ")
# Out:
#  traverse using for loop : 10 20 30 40 50

# %% [markdown]
# # 🔁 2. Using While Loop

# %%
arr = [10, 20, 30, 40, 50]
i = 0 
while i < len(arr): # 0 < 5, 1< 5
    print(arr[i], end = " ")
    i += 1
# Out:
# 10 20 30 40 50

# %% [markdown]
# # 🧾 3. Using Foreach Loop (in Python: for value in arr)

# %%
arr = [10,20,30,40,50]
for value in arr:
    print(value, end = " ")
# Out:
# 10 20 30 40 50

# %% [markdown]
# # 🛠️ Inserting Elements in an Array

# %% [markdown]
# # ✅ 1. Inserting at the Beginning

# %%
arr = [10,20,30,40,50]
ele = 100 
arr.insert(0,ele)

print("after inserstion:", arr)
# Out:
# after inserstion: [100, 10, 20, 30, 40, 50]

# %% [markdown]
# # 🎯 2. Inserting at a Given Position

# %%
arr = [10,20,30,40,50]
pos = 2
ele = 100 

arr.insert(pos-1,ele) #(2-1=1, 100)

print("after inserstion:", arr)
# Out:
# after inserstion: [10, 100, 20, 30, 40, 50]

# %% [markdown]
# # 🚀 3. Inserting at the End

# %%
arr = [10,20,30,40,50]
ele = 100 
arr.append(ele) 
print("after inserstion:", arr)
# Out:
# after inserstion: [10, 20, 30, 40, 50, 100]

# %% [markdown]
# # 4. Searching in Array

# %%
# 🔍 Linear Search in Unsorted Array
def FindElement(arr, n, key):
    for i in range(n): #i =0, i =1, i =2, i = 3, i =4
        if arr[i] == key: # 12 == 40,34 ==40,10 ==40,6==40, 40 == 40
            return i
    return -1        
arr = [12,34,10,6,40] 
key = 40
n = len(arr)  #5
index = FindElement(arr, n , key)
print(index)
# Out:
# 4

# %% [markdown]
# # 3. Deletion in Array

# %%
# Delete first element
arr = [12, 34,10,6,40]
del arr[0]
print("after dele at begnning:", arr)
# Out:
# after dele at begnning: [34, 10, 6, 40]

# %%
# ⚙️ 2. Deletion at a Specific Index


arr = [10, 20, 30, 40, 50]
index_to_del = 2 #30 = del
if 0 <= index_to_del < len(arr): # 0<=2 <5
    del arr[index_to_del]
print("after dele at index:", arr)
# Out:
# after dele at index: [10, 20, 40, 50]

# %%
# ⚙️ 3. Deletion at the End
arr = [10,20, 30,40 ,50]
arr.pop()
print("After deletion at end:", arr)
# Out:
# After deletion at end: [10, 20, 30, 40]
